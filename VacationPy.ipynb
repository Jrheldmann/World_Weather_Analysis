# %%
# Import the dependencies.
import pandas as pd
import requests
import matplotlib.pyplot as plt
# Import the API key.
from config import g_key

# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID            City Country                  Date      Lat      Lng  \
# 0        0          Albany      US  2022-09-08  01-14-37  42.6001 -73.9662
# 1        1          Dikson      RU  2022-09-08  01-12-12  73.5069  80.5464
# 2        2  Ribeira Grande      PT  2022-09-08  01-14-48  38.5167 -28.7000
# 3        3       Jamestown      US  2022-09-08  01-14-47  42.0970 -79.2353
# 4        4         Halifax      CA  2022-09-08  01-14-48  44.6453 -63.5724
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     64.35        92          48        2.39
# 1     37.31        88         100       20.69
# 2     75.36        90         100       19.35
# 3     65.17        72         100        5.75
# 4     62.60        89           0        1.14

# %%
# Get the data types.
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %%
# Import Google Maps dependency
import gmaps

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %%
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
temps = []
for temp in max_temp:
    temps.append(max(temp, 0))

# %%
# Heatmap of temperature
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
# Assign the figure variable.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
# Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp], 
                                 dissipating=False, max_intensity=300, point_radius=4)
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
humidity = city_data_df["Humidity"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent Cloudiness
locations = city_data_df[["Lat", "Lng"]]
clouds = city_data_df["Cloudiness"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=clouds, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of Wind Speed
locations = city_data_df[["Lat", "Lng"]]
wind = city_data_df["Wind Speed"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=wind, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature (F) you would like for your trip? "))
max_temp = float(input("What is the maximum temperature (F) you would like for your trip? "))
# Out:
# What is the minimum temperature (F) you would like for your trip? 75
# What is the maximum temperature (F) you would like for your trip? 90

# %%
# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID                  City Country                  Date      Lat  \
# 2         2        Ribeira Grande      PT  2022-09-08  01-14-48  38.5167
# 7         7            Georgetown      MY  2022-09-08  01-14-49   5.4112
# 8         8  Nova Olinda Do Norte      BR  2022-09-08  01-14-49  -3.8881
# 13       13            Butaritari      KI  2022-09-08  01-14-50   3.0707
# 14       14            Port Blair      IN  2022-09-08  01-11-35  11.6667
# 16       16                Hasaki      JP  2022-09-08  01-13-32  35.7333
# 18       18               Merauke      ID  2022-09-08  01-10-38  -8.4667
# 21       21             Pontianak      ID  2022-09-08  01-14-52  -0.0333
# 23       23                  Hilo      US  2022-09-08  01-14-53  19.7297
# 27       27                 Kapaa      US  2022-09-08  01-14-54  22.0752
#
#          Lng  Max Temp  Humidity  Cloudiness  Wind Speed
# 2   -28.7000     75.36        90         100       19.35
# 7   100.3354     81.90        89          20        4.61
# 8   -59.0942     83.93        51          96        2.33
# 13  172.7902     81.36        75          24       16.44
# 14   92.7500     79.59        85         100       19.73
# 16  140.8333     77.40        85          50       20.98
# 18  140.3333     83.41        73          96        9.98
# 21  109.3333     76.98        94          75        3.44
# 23 -155.0900     88.29        73           0        8.05
# 27 -159.3190     84.52        68          20       13.80

# %%
preferred_cities_df.count()
# Out:
# City_ID       179
# City          179
# Country       179
# Date          179
# Lat           179
# Lng           179
# Max Temp      179
# Humidity      179
# Cloudiness    179
# Wind Speed    179
# dtype: int64

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#                     City Country  Max Temp      Lat       Lng Hotel Name
# 2         Ribeira Grande      PT     75.36  38.5167  -28.7000
# 7             Georgetown      MY     81.90   5.4112  100.3354
# 8   Nova Olinda Do Norte      BR     83.93  -3.8881  -59.0942
# 13            Butaritari      KI     81.36   3.0707  172.7902
# 14            Port Blair      IN     79.59  11.6667   92.7500
# 16                Hasaki      JP     77.40  35.7333  140.8333
# 18               Merauke      ID     83.41  -8.4667  140.3333
# 21             Pontianak      ID     76.98  -0.0333  109.3333
# 23                  Hilo      US     88.29  19.7297 -155.0900
# 27                 Kapaa      US     84.52  22.0752 -159.3190

# %%
# Set the parameter to search for a hotel.
params = {"radius": 5000, "type": "lodging", "key": g_key,"location":_}

# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]
    
    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"
    
    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    # Grab the first hotel from the results and store the name.
    try:
        hotel_df.loc[index,"Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
pd.set_option("display.max_rows", None)
hotel_df
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
#                        City Country  Max Temp      Lat       Lng  \
# 2            Ribeira Grande      PT     75.36  38.5167  -28.7000
# 7                Georgetown      MY     81.90   5.4112  100.3354
# 8      Nova Olinda Do Norte      BR     83.93  -3.8881  -59.0942
# 13               Butaritari      KI     81.36   3.0707  172.7902
# 14               Port Blair      IN     79.59  11.6667   92.7500
# 16                   Hasaki      JP     77.40  35.7333  140.8333
# 18                  Merauke      ID     83.41  -8.4667  140.3333
# 21                Pontianak      ID     76.98  -0.0333  109.3333
# 23                     Hilo      US     88.29  19.7297 -155.0900
# 27                    Kapaa      US     84.52  22.0752 -159.3190
# 28              Gainesville      US     84.09  29.6516  -82.3248
# 29                   Avarua      CK     78.85 -21.2078 -159.7750
# 30                    Vaini      TO     82.56 -21.2000 -175.2000
# 32                   Turbat      PK     79.27  26.0023   63.0440
# 51                    Airai      TL     75.18  -8.9266  125.4092
# 52                Kavaratti      IN     79.32  10.5669   72.6420
# 58                  Yicheng      CN     79.59  31.3705  119.8703
# 60           Cabo San Lucas      MX     81.05  22.8909 -109.9124
# 61                   Atuona      PF     76.48  -9.8000 -139.0333
# 62                    Tabuk      PH     83.30  17.4189  121.4443
# 63                   Dwarka      IN     80.96  22.2394   68.9678
# 64               Sao Filipe      CV     78.67  14.8961  -24.4956
# 68                  Kahului      US     89.62  20.8947 -156.4700
# 70               Hambantota      LK     78.35   6.1241   81.1185
# 71                  Kavieng      PG     85.37  -2.5744  150.7967
# 74               Morant Bay      JM     83.82  17.8815  -76.4093
# 78            Pacific Grove      US     89.38  36.6177 -121.9166
# 83              Bandarbeyla      SO     76.98   9.4942   50.8122
# 91                  Tubuala      PA     78.76   9.5167  -79.0333
# 95                     Tura      IN     76.91  25.5198   90.2201
# 97                    Balad      IQ     88.38  34.0164   44.1453
# 98   Sao Miguel Do Araguaia      BR     81.86 -13.2750  -50.1628
# 101                  Vanimo      PG     83.77  -2.6741  141.3028
# 102               Hithadhoo      MV     82.04  -0.6000   73.0833
# 104           Marsh Harbour      BS     83.77  26.5412  -77.0636
# 110         Ambagarh Chauki      IN     75.96  20.7833   80.7167
# 112             San Quintin      MX     80.62  30.4833 -115.9500
# 113                   Lamar      US     83.64  33.6668  -95.5836
# 116                Bengkulu      ID     75.83  -3.8004  102.2655
# 118                   Jutai      BR     78.57  -5.1833  -68.9000
# 120                  Lyndon      US     75.54  38.2567  -85.6016
# 121        Praia Da Vitoria      PT     77.25  38.7333  -27.0667
# 124                    Tezu      IN     76.87  27.9167   96.1667
# 126                  Kailua      US     89.58  21.4022 -157.7394
# 135                  Faanui      PF     78.10 -16.4833 -151.7500
# 136              Kindersley      CA     75.22  51.4668 -109.1682
# 145             Paragominas      BR     78.67  -2.9667  -47.4833
# 151              Diamantino      BR     86.04 -14.4086  -56.4461
# 156               Namatanai      PG     85.60  -3.6667  152.4333
# 161                Victoria      HK     87.96  22.2855  114.1577
# 164                  Jiwani      PK     78.37  25.0500   61.7417
# 166                Lorengau      PG     85.10  -2.0226  147.2712
# 167            Fort Madison      US     76.01  40.6298  -91.3151
# 169           San Policarpo      PH     85.39  12.1791  125.5072
# 170               Mathbaria      BD     83.61  22.2876   89.9593
# 180                    Elko      US     89.62  41.0002 -115.5012
# 192                 Camapua      BR     81.97 -19.5314  -54.0439
# 200          Guerrero Negro      MX     77.50  27.9769 -114.0611
# 208                 Sharjah      AE     87.78  25.3573   55.4033
# 216                  Marzuq      YE     78.26  14.4000   46.4667
# 219                 Tautira      PF     77.18 -17.7333 -149.1500
# 224            Guayaramerin      BO     81.82 -10.8368  -65.3614
# 226                  Awbari      LY     79.88  26.5921   12.7805
# 230                  Lufkin      US     82.31  31.3382  -94.7291
# 234                   Nalut      LY     83.84  30.3333   10.8500
# 235                Tokoname      JP     78.87  34.8833  136.8500
# 237                   Korla      CN     78.75  41.7597   86.1469
# 239                Buchanan      LR     75.36   5.8808  -10.0467
# 240                  Sorong      ID     81.79  -0.8833  131.2500
# 241               Bathsheba      BB     83.01  13.2167  -59.5167
# 244                    Hami      CN     81.50  42.8000   93.4500
# 249           Fuerte Olimpo      PY     81.59 -21.0415  -57.8738
# 250                   Alofi      NU     82.29 -19.0595 -169.9187
# 254                 Samarai      PG     81.91 -10.6167  150.6667
# 257           Pointe Michel      DM     82.54  15.2500  -61.3833
# 261                 Sakakah      SA     81.97  29.9697   40.2064
# 262                    Nara      JP     82.49  34.6851  135.8049
# 264               Zhumadian      CN     79.07  32.9794  114.0294
# 266              Cerro Azul      MX     75.38  21.2000  -97.7333
# 272                 Shihezi      CN     81.39  44.3000   86.0333
# 273                  Pauini      BR     85.48  -7.7136  -66.9764
# 275                   Kathu      TH     86.76   7.9178   98.3332
# 276                Coos Bay      US     78.31  43.3665 -124.2179
# 278            Monaco-Ville      FR     76.64  43.7310    7.4248
# 279                 Shimoda      JP     77.36  34.6667  138.9500
# 281            San Patricio      US     84.15  28.0170  -97.5169
# 283                 Wucheng      CN     82.18  29.6008  118.1750
# 284               Gushikawa      JP     85.23  26.3544  127.8686
# 290              Luganville      VU     84.11 -15.5333  167.1667
# 296               Dalbandin      PK     81.99  28.8947   64.4101
# 298                Acapulco      MX     84.02  16.8634  -99.8901
# 301                Katsuura      JP     80.28  35.1333  140.3000
# 302                 Ransang      PH     84.51   8.9603  117.5828
# 304                 Camocim      BR     77.47  -2.9022  -40.8411
# 307                Tamiahua      MX     79.25  21.2667  -97.4500
# 308                     Eyl      SO     77.02   7.9803   49.8164
# 312                  Sinjar      IQ     81.61  36.3209   41.8754
# 316                  Urumqi      CN     77.95  43.8010   87.6005
# 318     Las Matas De Farfan      DO     77.00  18.8731  -71.5166
# 319              Coahuayana      MX     80.47  18.7333 -103.6833
# 320   Sant Feliu De Guixols      ES     77.29  41.7833    3.0333
# 325           Saint-Georges      GD     82.08  12.0564  -61.7485
# 326                 Cayenne      GF     75.24   4.9333  -52.3333
# 329                 Salalah      OM     77.09  17.0151   54.0924
# 332                   Hondo      JP     76.51  32.4500  130.2000
# 335                   Mutis      CO     78.28   6.2262  -77.4044
# 336                 Niquero      CU     80.42  20.0431  -77.5828
# 337         Charters Towers      AU     78.08 -20.1000  146.2667
# 338                    Miri      MY     82.54   4.4148  114.0089
# 339                     Hit      IQ     87.51  33.6416   42.8251
# 342                    Naze      JP     83.32  28.3667  129.4833
# 344                  Boende      CD     75.96  -0.2167   20.8667
# 346                  Dingle      PH     83.35  10.9995  122.6711
# 352                  Manado      ID     86.77   1.4870  124.8455
# 354              Pedernales      DO     81.68  18.0384  -71.7440
# 356                  Muroto      JP     80.35  33.2833  134.1500
# 357               Centralia      US     79.34  46.7162 -122.9543
# 358                  Yining      CN     75.97  29.0361  114.5636
# 365                     Bol      TD     80.60  13.4586   14.7147
# 368              Santa Rosa      PH     88.11  14.3122  121.1114
# 372            Collierville      US     78.80  35.0420  -89.6645
# 378                Bac Lieu      VN     78.67   9.2850  105.7244
# 384              Porto Novo      BJ     78.62   6.4965    2.6036
# 385                  Majene      ID     81.75  -3.5403  118.9707
# 390                  Ranong      TH     75.13   9.9658   98.6348
# 392                 Luorong      CN     80.98  24.4058  109.6086
# 393                 Baghdad      IQ     87.71  33.3406   44.4009
# 395        Senador Guiomard      BR     78.55 -10.1522  -67.7392
# 396                  Kirkuk      IQ     86.70  35.4681   44.3922
# 398                  Tukrah      LY     76.01  32.5341   20.5791
# 399               Mount Isa      AU     83.97 -20.7333  139.5000
# 401              Kalaikunda      IN     80.96  22.3500   87.2500
# 404                 Russell      US     77.97  32.3502  -85.1999
# 405                 Isangel      VU     80.96 -19.5500  169.2667
# 409               Pemangkat      ID     78.33   1.1667  108.9667
# 410                  Lethem      GY     77.47   3.3803  -59.7968
# 412           Puerto Madero      MX     79.00  14.7208  -92.4215
# 415                   Matay      EG     76.69  28.4190   30.7792
# 416                  Linfen      CN     78.48  36.0889  111.5189
# 418           San Cristobal      VE     77.18   7.7669  -72.2250
# 425               Gorontalo      ID     84.36   0.5412  123.0595
# 430                   Praya      CV     79.34  14.9215  -23.5087
# 435                 Sumenep      ID     83.59  -7.0167  113.8667
# 438                   Nizwa      OM     76.24  22.9333   57.5333
# 441                     Gat      IL     75.88  31.6100   34.7642
# 445                  Mantua      IT     76.15  45.1667   10.7833
# 449                   Mahon      ES     79.36  39.8885    4.2658
# 454                    Biak      ID     80.69  -0.9131  122.8766
# 455                  Sabang      ID     82.33   5.8933   95.3214
# 456                  Rafraf      TN     86.31  37.1904   10.1837
# 466                Galesong      ID     82.42  -5.3166  119.3661
# 468                  Sokolo      ML     79.29  14.7328   -6.1219
# 470             Keti Bandar      PK     80.10  24.1447   67.4497
# 471                  Gerash      IR     75.34  27.6652   54.1371
# 474                  Davila      PH     84.18  18.4726  120.5763
# 481            North Platte      US     86.11  41.1239 -100.7654
# 490                Yavatmal      IN     75.07  20.4000   78.1333
# 492                Portland      US     80.29  45.5234 -122.6762
# 493                  Shiyan      CN     77.77  32.6475  110.7781
# 494              Moss Point      US     78.26  30.4116  -88.5345
# 496                Kawardha      IN     76.42  22.0167   81.2500
# 498                     Soe      ID     80.42  -9.8607  124.2840
# 501              North Bend      US     78.24  43.4065 -124.2243
# 504             Sakaiminato      JP     80.58  35.5500  133.2333
# 505                   Buala      SB     84.67  -8.1450  159.5921
# 513                   Chase      CA     79.09  50.8165 -119.6857
# 515                 Baculin      PH     84.58   7.4525  126.5842
# 516           Ponta Delgada      PT     79.50  37.7333  -25.6667
# 518                  Rincon      US     83.86  32.2960  -81.2354
# 519              Banda Aceh      ID     80.74   5.5577   95.3222
# 521               Kununurra      AU     87.78 -15.7667  128.7333
# 524              Hutchinson      US     84.04  38.0608  -97.9298
# 525               Ugoofaaru      MV     80.85   5.6667   73.0000
# 528            Port Hedland      AU     75.25 -20.3167  118.5667
# 530                  Barmer      IN     84.11  25.7500   71.3833
# 539                   Thoen      TH     77.67  17.6129   99.2161
# 541              Sungairaya      ID     79.50   0.7000  108.9000
# 542            Kudahuvadhoo      MV     82.17   2.6708   72.8944
# 543                   Nador      MA     80.85  35.1740   -2.9287
#
#                                             Hotel Name
# 2                                  Quinta da Meia Eira
# 7                                       Cititel Penang
# 8                                        Casa Juazeiro
# 13                                  Isles Sunset Lodge
# 14   Welcomhotel By ITC Hotels, Bay Island, Port Blair
# 16                               Inubosaki Kanko Hotel
# 18
# 21           Aston Pontianak Hotel & Convention Center
# 23                                 Hilo Hawaiian Hotel
# 27                 Sheraton Kauai Coconut Beach Resort
# 28                                     Stayable Select
# 29                                        Paradise Inn
# 30                                 Keleti Beach Resort
# 32                                   Mubashar Quarters
# 51
# 52                                          Green leaf
# 58   GreenTree Alliance Wuxi Yixing Jinyizhong Road...
# 60                              Hotel Tesoro Los Cabos
# 61                         Hôtel Hiva Oa Hanakee Lodge
# 62                 Golden Berries Hotel and Convention
# 63                       Hotel Narayan Avezika Comfort
# 64                                       Hotel Xaguate
# 68                                  Maui Seaside Hotel
# 70                                         Bungalow 63
# 71                                 Nusa Island Retreat
# 74                       Whispering Bamboo Cove Resort
# 78                                    Lovers Point Inn
# 83                                         JABIR HOTEL
# 91
# 95                            Hotel RIKMAN Continental
# 97                                         رضاوي زنوبة
# 98                              Hotel Executivo Palace
# 101                              Vahmoneh Lodge Vanimo
# 102                                  Scoop Guest House
# 104                                 Abaco Beach Resort
# 110                    गाँधी चौक शांति भवन सोनसाय टोला
# 112                   Don Eddie's Sport Fishing Center
# 113                                 Kings Inn Paris TX
# 116                               Grage Hotel Bengkulu
# 118
# 120  SpringHill Suites by Marriott Louisville Hurst...
# 121                                     Hotel Branco I
# 124                                      Circuit House
# 126                    Sheffield House Bed & Breakfast
# 135                 Bora-Bora Pearl Beach Resort & Spa
# 136                                     Kindersley Inn
# 145                                              INOVA
# 151                                        Hotel Delta
# 156                              Seagulls Inn Namatani
# 161                                       Mini Central
# 164
# 166                         Lorengau Harbourside Hotel
# 167                                       Kingsley Inn
# 169                                  Agapita M. Nicart
# 170                                      Shikdar Hotel
# 180
# 192                                  Comercial Estrela
# 200                       Casa Laguna, Bed & Breakfast
# 208                             Swiss Belhotel Sharjah
# 216                                         حيد القفلة
# 219                                       Pension Oaoa
# 224                                        Hostal FÜNF
# 226                                        فندق أوباري
# 230                       Courtyard by Marriott Lufkin
# 234
# 235  Toyoko INN Chubu International Airport main bu...
# 237                                    Gulisitan Hotel
# 239                                Kamaneahn Hotel Inc
# 240                                 Waigo Splash Hotel
# 241                                     Atlantis Hotel
# 244                                   Laoyutang Resort
# 249                                     Hospedaje DAMI
# 250                                      Taloa Heights
# 254                                          Nuli Sapi
# 257               Roseau Hostel & Beach Front Property
# 261                      Fakhamat Al Orjoana Apartment
# 262                            Guesthouse Nara Komachi
# 264                                  Ouyue House Hotel
# 266                                     Hotel Colonial
# 272        Home Inn Shihezi Dongwu Road Century Square
# 273                                    Casa do Kiwliks
# 275                              Novotel Phuket Resort
# 276                         Best Western Holiday Hotel
# 278                            Le Méridien Beach Plaza
# 279                                Shimoda Tokyu Hotel
# 281                                 Motel 6 Sinton, TX
# 283                                   Xiuwu Restaurant
# 284                                 Kirari Guest House
# 290                                 The Espiritu Hotel
# 296                                     Sanjrani House
# 298                          HS Hotsson Smart Acapulco
# 301                            Katsuura Hotel Mikazuki
# 302                    Black and Crystal Sand Campsite
# 304                                   Ilha Praia Hotel
# 307                           Mission Of The Sun Hotel
# 308                                        Amiin Hotel
# 312                                       زوماني فون 1
# 316                        Hua Ling Grand Hotel Urumqi
# 318                                  Breathless Resort
# 319                  El rranchito michuacan de ocampos
# 320                                    Hotel NM Suites
# 325                      Radisson Grenada Beach Resort
# 326                                    Hôtel Le Dronmi
# 329           HAMDAN PLAZA HOTEL SALALAH, an HTG Hotel
# 332                                              ホテル河丁
# 335                                  Paraiso Escondido
# 336                                    Islazul Niquero
# 337                         Cattleman's Rest Motor Inn
# 338                                   Mega Hotel, Miri
# 339                                    ࢪُبَمـا ؏ُـمَـࢪ
# 342                                     Shishime Hotel
# 344
# 346                                    SEGAYA PROPERTY
# 352                                     Aryaduta Hotel
# 354                                 Hotel Costa Marina
# 356                                        Oota Ryokan
# 357                                     Peppermill Inn
# 358                                      Xiushui Hotel
# 365                           Harrouni camp de passage
# 368                         Erlyn’s Sta Rosa City Home
# 372                   Hampton Inn Memphis/Collierville
# 378                         Khách sạn Sài Gòn Bạc Liêu
# 384                            Tour Eiffel Hotel Benin
# 385                                 Kost Putri RABBANI
# 390                      Numsai Khaosuay Resort Ranong
# 392                                              荣立大酒店
# 393                                      Baghdad Hotel
# 395                                      Paraíso Hotel
# 396                                        Cihad Oteli
# 398                                 Lagrota restaurant
# 399                          ibis Styles Mt Isa Verona
# 401                                     Hotel Capsicum
# 404                                               Macs
# 405                                        Tanna Lodge
# 409                              Hotel Duyung Permai 2
# 410                                       Savannah Inn
# 412                          DEPARTAMENTOS LA ESTANCIA
# 415                                         Nag Aespen
# 416                                      Suoxing Hotel
# 418                                           Pirineos
# 425                           Maqna Hotel by Prasanthi
# 430                                      LT Aparthotel
# 435                          OYO 3271 Homestay Pandian
# 438                                  Orient Apartments
# 441                                           OlusHome
# 445                                  Hotel la Favorita
# 449                                       ARTIEM Capri
# 454                                     Penginapan Kim
# 455                                        Hotel Citra
# 456                 Les Jardins de la Mer Ghar el Melh
# 466                                      Sapriadi Appy
# 468
# 470                             Haji laloo memon house
# 471                               Sa'adat House Gerash
# 474                            Blue Ridge Beach Resort
# 481  Holiday Inn Express & Suites North Platte, an ...
# 490                                         Palash Inn
# 492         Embassy Suites by Hilton Portland Downtown
# 493                     Fenghuang Garden Holiday Hotel
# 494  Holiday Inn Express Pascagoula-Moss Point, an ...
# 496                   STARiHOTELS Raipur Road kawardha
# 498                                         Dena Hotel
# 501                            Red Lion Hotel Coos Bay
# 504                                     Italian pasley
# 505                               Maringe Lagoon Lodge
# 513                            Chase Country Inn Motel
# 515                          Baculin Cove Beach Resort
# 516                                    Vila Nova Hotel
# 518                                    Days Inn Rincon
# 519                            OYO 884 Rumoh PMI Hotel
# 521                                    Hotel Kununurra
# 524                             Hampton Inn Hutchinson
# 525                                     Ungoofaaru Inn
# 528                                The Esplanade Hotel
# 530                                   Jain Dharamshala
# 539                                        บ้านห้องนอน
# 541                           Rumah Kuku Moimoi Shelly
# 542                    Niyama Private Islands Maldives
# 543                                   Hôtel La Giralda

# %%
# Add a heatmap of temperature for the vacation spots.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp, 
                                 dissipating=False,
             max_intensity=300, point_radius=4)

# Create locations marker layer
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)

fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""
# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests as rq
from config import weather_api_key
import time

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combo.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 756

# %%
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create the counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(3)
        
    #Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve the data.
        city_weather = rq.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country,
                         "Current Description": city_weather_desc})
# If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate the Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | yar-sale
# Processing Record 2 of Set 1 | cape town
# Processing Record 3 of Set 1 | cherskiy
# Processing Record 4 of Set 1 | ponta do sol
# Processing Record 5 of Set 1 | sawakin
# Processing Record 6 of Set 1 | chokurdakh
# Processing Record 7 of Set 1 | upernavik
# Processing Record 8 of Set 1 | utamysh
# Processing Record 9 of Set 1 | atuona
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | muyezerskiy
# Processing Record 12 of Set 1 | nikolskoye
# Processing Record 13 of Set 1 | kapaa
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | bluff
# Processing Record 17 of Set 1 | thompson
# Processing Record 18 of Set 1 | puerto ayora
# Processing Record 19 of Set 1 | coquimbo
# Processing Record 20 of Set 1 | torres
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | souillac
# Processing Record 23 of Set 1 | padang
# Processing Record 24 of Set 1 | kodiak
# Processing Record 25 of Set 1 | rikitea
# Processing Record 26 of Set 1 | webuye
# Processing Record 27 of Set 1 | kaliganj
# Processing Record 28 of Set 1 | ponta delgada
# Processing Record 29 of Set 1 | burica
# City not found. Skipping...
# Processing Record 30 of Set 1 | jieshi
# Processing Record 31 of Set 1 | provideniya
# Processing Record 32 of Set 1 | enid
# Processing Record 33 of Set 1 | ulaangom
# Processing Record 34 of Set 1 | saryshagan
# City not found. Skipping...
# Processing Record 35 of Set 1 | sosnovka
# Processing Record 36 of Set 1 | bredasdorp
# Processing Record 37 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 1 | killybegs
# Processing Record 39 of Set 1 | carnarvon
# Processing Record 40 of Set 1 | tessalit
# Processing Record 41 of Set 1 | matagami
# Processing Record 42 of Set 1 | broome
# Processing Record 43 of Set 1 | geraldton
# Processing Record 44 of Set 1 | mount gambier
# Processing Record 45 of Set 1 | castro
# Processing Record 46 of Set 1 | taltal
# Processing Record 47 of Set 1 | hermanus
# Processing Record 48 of Set 1 | sao filipe
# Processing Record 49 of Set 1 | berezovyy
# Processing Record 50 of Set 1 | ahuimanu
# Processing Record 1 of Set 2 | avarua
# Processing Record 2 of Set 2 | sechura
# Processing Record 3 of Set 2 | vaini
# Processing Record 4 of Set 2 | rodrigues alves
# Processing Record 5 of Set 2 | hithadhoo
# Processing Record 6 of Set 2 | katherine
# Processing Record 7 of Set 2 | puerto escondido
# Processing Record 8 of Set 2 | pevek
# Processing Record 9 of Set 2 | namatanai
# Processing Record 10 of Set 2 | kieta
# Processing Record 11 of Set 2 | portland
# Processing Record 12 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 2 | merauke
# Processing Record 14 of Set 2 | gumushane
# City not found. Skipping...
# Processing Record 15 of Set 2 | atasu
# Processing Record 16 of Set 2 | tuktoyaktuk
# Processing Record 17 of Set 2 | yangjiang
# Processing Record 18 of Set 2 | atar
# Processing Record 19 of Set 2 | eureka
# Processing Record 20 of Set 2 | georgetown
# Processing Record 21 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 2 | owando
# Processing Record 23 of Set 2 | pisco
# Processing Record 24 of Set 2 | norman wells
# Processing Record 25 of Set 2 | longyearbyen
# Processing Record 26 of Set 2 | jamestown
# Processing Record 27 of Set 2 | comodoro rivadavia
# Processing Record 28 of Set 2 | nouadhibou
# Processing Record 29 of Set 2 | makakilo city
# Processing Record 30 of Set 2 | san carlos
# Processing Record 31 of Set 2 | oktyabrskoye
# Processing Record 32 of Set 2 | luderitz
# Processing Record 33 of Set 2 | vanimo
# Processing Record 34 of Set 2 | east london
# Processing Record 35 of Set 2 | lebu
# Processing Record 36 of Set 2 | sibolga
# Processing Record 37 of Set 2 | saint-francois
# Processing Record 38 of Set 2 | butaritari
# Processing Record 39 of Set 2 | berlevag
# Processing Record 40 of Set 2 | omboue
# Processing Record 41 of Set 2 | poum
# Processing Record 42 of Set 2 | juazeiro
# Processing Record 43 of Set 2 | santa cruz del sur
# Processing Record 44 of Set 2 | ingham
# Processing Record 45 of Set 2 | satitoa
# City not found. Skipping...
# Processing Record 46 of Set 2 | mafinga
# Processing Record 47 of Set 2 | tuatapere
# Processing Record 48 of Set 2 | mangrol
# Processing Record 49 of Set 2 | hobart
# Processing Record 50 of Set 2 | dawei
# Processing Record 1 of Set 3 | aykhal
# Processing Record 2 of Set 3 | trier
# Processing Record 3 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 3 | aitape
# Processing Record 5 of Set 3 | ayagoz
# Processing Record 6 of Set 3 | iquique
# Processing Record 7 of Set 3 | tsogni
# Processing Record 8 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 3 | taoudenni
# Processing Record 10 of Set 3 | clyde river
# Processing Record 11 of Set 3 | matay
# Processing Record 12 of Set 3 | teya
# Processing Record 13 of Set 3 | sokoni
# Processing Record 14 of Set 3 | saskylakh
# Processing Record 15 of Set 3 | kosh-agach
# Processing Record 16 of Set 3 | dzhusaly
# City not found. Skipping...
# Processing Record 17 of Set 3 | coihaique
# Processing Record 18 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 3 | itarema
# Processing Record 20 of Set 3 | san patricio
# Processing Record 21 of Set 3 | desaguadero
# Processing Record 22 of Set 3 | albany
# Processing Record 23 of Set 3 | half moon bay
# Processing Record 24 of Set 3 | lorengau
# Processing Record 25 of Set 3 | talnakh
# Processing Record 26 of Set 3 | mount isa
# Processing Record 27 of Set 3 | bavly
# Processing Record 28 of Set 3 | hamilton
# Processing Record 29 of Set 3 | zaliztsi
# Processing Record 30 of Set 3 | victoria point
# Processing Record 31 of Set 3 | khatanga
# Processing Record 32 of Set 3 | chuy
# Processing Record 33 of Set 3 | mar del plata
# Processing Record 34 of Set 3 | beyneu
# Processing Record 35 of Set 3 | manyana
# Processing Record 36 of Set 3 | bilibino
# Processing Record 37 of Set 3 | iqaluit
# Processing Record 38 of Set 3 | abu dhabi
# Processing Record 39 of Set 3 | port elizabeth
# Processing Record 40 of Set 3 | chapais
# Processing Record 41 of Set 3 | saint-philippe
# Processing Record 42 of Set 3 | mnogovershinnyy
# Processing Record 43 of Set 3 | saint-joseph
# Processing Record 44 of Set 3 | burnie
# Processing Record 45 of Set 3 | yulara
# Processing Record 46 of Set 3 | martapura
# Processing Record 47 of Set 3 | sao gabriel da cachoeira
# Processing Record 48 of Set 3 | shingu
# Processing Record 49 of Set 3 | nabire
# Processing Record 50 of Set 3 | new norfolk
# Processing Record 1 of Set 4 | ilulissat
# Processing Record 2 of Set 4 | dijkot
# Processing Record 3 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 4 of Set 4 | bara
# Processing Record 5 of Set 4 | narsaq
# Processing Record 6 of Set 4 | beloha
# Processing Record 7 of Set 4 | qaanaaq
# Processing Record 8 of Set 4 | mae tha
# Processing Record 9 of Set 4 | maceio
# Processing Record 10 of Set 4 | sabya
# Processing Record 11 of Set 4 | cockburn town
# Processing Record 12 of Set 4 | manjeshwar
# Processing Record 13 of Set 4 | manavalakurichi
# Processing Record 14 of Set 4 | haimen
# Processing Record 15 of Set 4 | port alfred
# Processing Record 16 of Set 4 | dikson
# Processing Record 17 of Set 4 | te anau
# Processing Record 18 of Set 4 | port blair
# Processing Record 19 of Set 4 | gamba
# Processing Record 20 of Set 4 | severnyy
# Processing Record 21 of Set 4 | byron bay
# Processing Record 22 of Set 4 | bath
# Processing Record 23 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 4 | san cristobal
# Processing Record 25 of Set 4 | cap malheureux
# Processing Record 26 of Set 4 | sur
# Processing Record 27 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 4 | khandyga
# Processing Record 29 of Set 4 | henties bay
# Processing Record 30 of Set 4 | labuhan
# Processing Record 31 of Set 4 | northam
# Processing Record 32 of Set 4 | arraial do cabo
# Processing Record 33 of Set 4 | tucurui
# Processing Record 34 of Set 4 | alihe
# Processing Record 35 of Set 4 | dolzhanskaya
# Processing Record 36 of Set 4 | sereflikochisar
# Processing Record 37 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 38 of Set 4 | bethel
# Processing Record 39 of Set 4 | matara
# Processing Record 40 of Set 4 | macaboboni
# City not found. Skipping...
# Processing Record 41 of Set 4 | torbay
# Processing Record 42 of Set 4 | suchedniow
# Processing Record 43 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 4 | tasiilaq
# Processing Record 45 of Set 4 | ribeira grande
# Processing Record 46 of Set 4 | bafq
# Processing Record 47 of Set 4 | los llanos de aridane
# Processing Record 48 of Set 4 | beringovskiy
# Processing Record 49 of Set 4 | faya
# Processing Record 50 of Set 4 | houma
# Processing Record 1 of Set 5 | payo
# Processing Record 2 of Set 5 | port lincoln
# Processing Record 3 of Set 5 | the valley
# Processing Record 4 of Set 5 | marsa matruh
# Processing Record 5 of Set 5 | barrow
# Processing Record 6 of Set 5 | anadyr
# Processing Record 7 of Set 5 | ouesso
# Processing Record 8 of Set 5 | gat
# Processing Record 9 of Set 5 | roald
# Processing Record 10 of Set 5 | meadow lake
# Processing Record 11 of Set 5 | emerald
# Processing Record 12 of Set 5 | umm kaddadah
# Processing Record 13 of Set 5 | kurush
# Processing Record 14 of Set 5 | oyama
# Processing Record 15 of Set 5 | morant bay
# Processing Record 16 of Set 5 | fortuna
# Processing Record 17 of Set 5 | timmins
# Processing Record 18 of Set 5 | oytal
# Processing Record 19 of Set 5 | snezhnogorsk
# Processing Record 20 of Set 5 | mahebourg
# Processing Record 21 of Set 5 | wawa
# Processing Record 22 of Set 5 | yellowknife
# Processing Record 23 of Set 5 | saint-pierre
# Processing Record 24 of Set 5 | san pascual
# Processing Record 25 of Set 5 | syasstroy
# Processing Record 26 of Set 5 | manika
# Processing Record 27 of Set 5 | palmerston
# Processing Record 28 of Set 5 | hilo
# Processing Record 29 of Set 5 | luang prabang
# Processing Record 30 of Set 5 | taylor
# Processing Record 31 of Set 5 | sinnamary
# Processing Record 32 of Set 5 | san rafael
# Processing Record 33 of Set 5 | moerai
# Processing Record 34 of Set 5 | vila velha
# Processing Record 35 of Set 5 | tocopilla
# Processing Record 36 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 5 | lamu
# Processing Record 38 of Set 5 | narsimhapur
# Processing Record 39 of Set 5 | smidovich
# Processing Record 40 of Set 5 | dunedin
# Processing Record 41 of Set 5 | lasa
# Processing Record 42 of Set 5 | grindavik
# Processing Record 43 of Set 5 | klaksvik
# Processing Record 44 of Set 5 | agadir
# Processing Record 45 of Set 5 | lagos
# Processing Record 46 of Set 5 | nassjo
# Processing Record 47 of Set 5 | ahipara
# Processing Record 48 of Set 5 | sardhana
# Processing Record 49 of Set 5 | kindu
# Processing Record 50 of Set 5 | bayir
# Processing Record 1 of Set 6 | meulaboh
# Processing Record 2 of Set 6 | saint george
# Processing Record 3 of Set 6 | katsuura
# Processing Record 4 of Set 6 | nanortalik
# Processing Record 5 of Set 6 | zeya
# Processing Record 6 of Set 6 | ussel
# Processing Record 7 of Set 6 | westport
# Processing Record 8 of Set 6 | sept-iles
# Processing Record 9 of Set 6 | artyk
# City not found. Skipping...
# Processing Record 10 of Set 6 | doha
# Processing Record 11 of Set 6 | mayo
# Processing Record 12 of Set 6 | kungurtug
# Processing Record 13 of Set 6 | nagram
# Processing Record 14 of Set 6 | laguna
# Processing Record 15 of Set 6 | te kauwhata
# Processing Record 16 of Set 6 | maningrida
# Processing Record 17 of Set 6 | altay
# Processing Record 18 of Set 6 | grass valley
# Processing Record 19 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 20 of Set 6 | jalu
# Processing Record 21 of Set 6 | lagoa
# Processing Record 22 of Set 6 | antanifotsy
# Processing Record 23 of Set 6 | inhambane
# Processing Record 24 of Set 6 | tarragona
# Processing Record 25 of Set 6 | menongue
# Processing Record 26 of Set 6 | alyangula
# Processing Record 27 of Set 6 | caravelas
# Processing Record 28 of Set 6 | dallas
# Processing Record 29 of Set 6 | bengkulu
# Processing Record 30 of Set 6 | carutapera
# Processing Record 31 of Set 6 | puerto leguizamo
# Processing Record 32 of Set 6 | riberalta
# Processing Record 33 of Set 6 | ixtapa
# Processing Record 34 of Set 6 | camopi
# Processing Record 35 of Set 6 | mandalgovi
# Processing Record 36 of Set 6 | groton
# Processing Record 37 of Set 6 | lavrentiya
# Processing Record 38 of Set 6 | oistins
# Processing Record 39 of Set 6 | ostrovnoy
# Processing Record 40 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 41 of Set 6 | sharjah
# Processing Record 42 of Set 6 | nhulunbuy
# Processing Record 43 of Set 6 | lisala
# Processing Record 44 of Set 6 | morondava
# Processing Record 45 of Set 6 | aklavik
# Processing Record 46 of Set 6 | dashitou
# Processing Record 47 of Set 6 | copiapo
# Processing Record 48 of Set 6 | kloulklubed
# Processing Record 49 of Set 6 | vostok
# Processing Record 50 of Set 6 | nuuk
# Processing Record 1 of Set 7 | palmer
# Processing Record 2 of Set 7 | yaan
# Processing Record 3 of Set 7 | bogen
# Processing Record 4 of Set 7 | general roca
# Processing Record 5 of Set 7 | douglas
# Processing Record 6 of Set 7 | nha trang
# Processing Record 7 of Set 7 | airai
# Processing Record 8 of Set 7 | bolobo
# Processing Record 9 of Set 7 | puerto cortes
# City not found. Skipping...
# Processing Record 10 of Set 7 | grand-lahou
# Processing Record 11 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 12 of Set 7 | acarau
# Processing Record 13 of Set 7 | beni
# Processing Record 14 of Set 7 | sennoy
# Processing Record 15 of Set 7 | machali
# Processing Record 16 of Set 7 | port hedland
# Processing Record 17 of Set 7 | wasilla
# Processing Record 18 of Set 7 | tura
# Processing Record 19 of Set 7 | novokruchininskiy
# Processing Record 20 of Set 7 | tomatlan
# Processing Record 21 of Set 7 | rundu
# Processing Record 22 of Set 7 | tazovskiy
# Processing Record 23 of Set 7 | abu kamal
# Processing Record 24 of Set 7 | zhangjiakou
# Processing Record 25 of Set 7 | borogontsy
# Processing Record 26 of Set 7 | sambava
# Processing Record 27 of Set 7 | cervo
# Processing Record 28 of Set 7 | hami
# Processing Record 29 of Set 7 | pachino
# Processing Record 30 of Set 7 | salalah
# Processing Record 31 of Set 7 | smoky lake
# Processing Record 32 of Set 7 | ancud
# Processing Record 33 of Set 7 | ariquemes
# Processing Record 34 of Set 7 | dukat
# Processing Record 35 of Set 7 | conselheiro lafaiete
# Processing Record 36 of Set 7 | mezen
# Processing Record 37 of Set 7 | brufut
# Processing Record 38 of Set 7 | bubaque
# Processing Record 39 of Set 7 | tolaga bay
# Processing Record 40 of Set 7 | upala
# Processing Record 41 of Set 7 | victoria
# Processing Record 42 of Set 7 | belmonte
# Processing Record 43 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 7 | klyuchi
# Processing Record 45 of Set 7 | manhattan
# Processing Record 46 of Set 7 | flin flon
# Processing Record 47 of Set 7 | qorveh
# Processing Record 48 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 7 | dingle
# Processing Record 50 of Set 7 | verkhnyaya inta
# Processing Record 1 of Set 8 | cidreira
# Processing Record 2 of Set 8 | vila franca do campo
# Processing Record 3 of Set 8 | changying
# Processing Record 4 of Set 8 | zhigansk
# Processing Record 5 of Set 8 | surt
# Processing Record 6 of Set 8 | huanren
# Processing Record 7 of Set 8 | saldanha
# Processing Record 8 of Set 8 | komyshuvakha
# Processing Record 9 of Set 8 | nampa
# Processing Record 10 of Set 8 | nioro
# Processing Record 11 of Set 8 | afmadu
# City not found. Skipping...
# Processing Record 12 of Set 8 | esperance
# Processing Record 13 of Set 8 | san quintin
# Processing Record 14 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 8 | deputatskiy
# Processing Record 16 of Set 8 | porto velho
# Processing Record 17 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 18 of Set 8 | gold coast
# Processing Record 19 of Set 8 | huarmey
# Processing Record 20 of Set 8 | kenai
# Processing Record 21 of Set 8 | flinders
# Processing Record 22 of Set 8 | waingapu
# Processing Record 23 of Set 8 | birao
# Processing Record 24 of Set 8 | borazjan
# Processing Record 25 of Set 8 | rio grande
# Processing Record 26 of Set 8 | skibbereen
# Processing Record 27 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 8 | skelleftea
# Processing Record 29 of Set 8 | fukue
# Processing Record 30 of Set 8 | kabompo
# Processing Record 31 of Set 8 | sri aman
# Processing Record 32 of Set 8 | cayenne
# Processing Record 33 of Set 8 | takoradi
# Processing Record 34 of Set 8 | svetlyy
# Processing Record 35 of Set 8 | qaqortoq
# Processing Record 36 of Set 8 | rabo de peixe
# Processing Record 37 of Set 8 | kavieng
# Processing Record 38 of Set 8 | rawson
# Processing Record 39 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 8 | tilichiki
# Processing Record 41 of Set 8 | ambon
# Processing Record 42 of Set 8 | kayerkan
# Processing Record 43 of Set 8 | cabo san lucas
# Processing Record 44 of Set 8 | cotonou
# Processing Record 45 of Set 8 | shaunavon
# Processing Record 46 of Set 8 | abu zabad
# Processing Record 47 of Set 8 | hounde
# Processing Record 48 of Set 8 | cumaribo
# City not found. Skipping...
# Processing Record 49 of Set 8 | lang son
# Processing Record 50 of Set 8 | churu
# Processing Record 1 of Set 9 | camacupa
# Processing Record 2 of Set 9 | aragarcas
# Processing Record 3 of Set 9 | kiama
# Processing Record 4 of Set 9 | osa
# Processing Record 5 of Set 9 | kaduqli
# Processing Record 6 of Set 9 | maniitsoq
# Processing Record 7 of Set 9 | visnes
# Processing Record 8 of Set 9 | ajdabiya
# Processing Record 9 of Set 9 | loreto
# Processing Record 10 of Set 9 | orocue
# Processing Record 11 of Set 9 | sorland
# Processing Record 12 of Set 9 | luba
# Processing Record 13 of Set 9 | la ronge
# Processing Record 14 of Set 9 | roquetas de mar
# Processing Record 15 of Set 9 | wynyard
# Processing Record 16 of Set 9 | whitehorse
# Processing Record 17 of Set 9 | aldergrove
# Processing Record 18 of Set 9 | taikang
# Processing Record 19 of Set 9 | cacoal
# Processing Record 20 of Set 9 | chkalovsk
# Processing Record 21 of Set 9 | haibowan
# City not found. Skipping...
# Processing Record 22 of Set 9 | khasan
# Processing Record 23 of Set 9 | port macquarie
# Processing Record 24 of Set 9 | cabedelo
# Processing Record 25 of Set 9 | faanui
# Processing Record 26 of Set 9 | farafangana
# Processing Record 27 of Set 9 | black river
# Processing Record 28 of Set 9 | san nicolas
# Processing Record 29 of Set 9 | ambulu
# Processing Record 30 of Set 9 | galchino
# City not found. Skipping...
# Processing Record 31 of Set 9 | kruisfontein
# Processing Record 32 of Set 9 | balimo
# City not found. Skipping...
# Processing Record 33 of Set 9 | leningradskiy
# Processing Record 34 of Set 9 | gao
# Processing Record 35 of Set 9 | sakakah
# Processing Record 36 of Set 9 | pochutla
# Processing Record 37 of Set 9 | guerrero negro
# Processing Record 38 of Set 9 | nadym
# Processing Record 39 of Set 9 | teluknaga
# Processing Record 40 of Set 9 | seoul
# Processing Record 41 of Set 9 | myrtle grove
# Processing Record 42 of Set 9 | sao joao da barra
# Processing Record 43 of Set 9 | camacha
# Processing Record 44 of Set 9 | uberlandia
# Processing Record 45 of Set 9 | iralaya
# Processing Record 46 of Set 9 | sitka
# Processing Record 47 of Set 9 | cairns
# Processing Record 48 of Set 9 | codrington
# Processing Record 49 of Set 9 | tres arroyos
# Processing Record 50 of Set 9 | termiz
# Processing Record 1 of Set 10 | kilimatinde
# Processing Record 2 of Set 10 | ratlam
# Processing Record 3 of Set 10 | asau
# Processing Record 4 of Set 10 | punto fijo
# Processing Record 5 of Set 10 | aswan
# Processing Record 6 of Set 10 | portree
# Processing Record 7 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 8 of Set 10 | opelousas
# Processing Record 9 of Set 10 | tiksi
# Processing Record 10 of Set 10 | komsomolskiy
# Processing Record 11 of Set 10 | kahului
# Processing Record 12 of Set 10 | trat
# Processing Record 13 of Set 10 | mujiayingzi
# Processing Record 14 of Set 10 | vao
# Processing Record 15 of Set 10 | jumla
# Processing Record 16 of Set 10 | senneterre
# Processing Record 17 of Set 10 | wanlaweyn
# Processing Record 18 of Set 10 | longhua
# Processing Record 19 of Set 10 | fort morgan
# Processing Record 20 of Set 10 | sinjar
# Processing Record 21 of Set 10 | yamada
# Processing Record 22 of Set 10 | gumdag
# Processing Record 23 of Set 10 | iznik
# Processing Record 24 of Set 10 | tommot
# Processing Record 25 of Set 10 | vestmannaeyjar
# Processing Record 26 of Set 10 | vilhena
# Processing Record 27 of Set 10 | koumra
# Processing Record 28 of Set 10 | erenhot
# Processing Record 29 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 30 of Set 10 | navashino
# Processing Record 31 of Set 10 | patti
# Processing Record 32 of Set 10 | fort nelson
# Processing Record 33 of Set 10 | balkhash
# Processing Record 34 of Set 10 | takestan
# Processing Record 35 of Set 10 | samarai
# Processing Record 36 of Set 10 | korla
# Processing Record 37 of Set 10 | kalmunai
# Processing Record 38 of Set 10 | lukow
# Processing Record 39 of Set 10 | nelson bay
# Processing Record 40 of Set 10 | kudahuvadhoo
# Processing Record 41 of Set 10 | melendugno
# Processing Record 42 of Set 10 | cabinda
# Processing Record 43 of Set 10 | presidencia roque saenz pena
# Processing Record 44 of Set 10 | abu jubayhah
# City not found. Skipping...
# Processing Record 45 of Set 10 | manakara
# Processing Record 46 of Set 10 | champerico
# Processing Record 47 of Set 10 | fairbanks
# Processing Record 48 of Set 10 | tsabong
# Processing Record 49 of Set 10 | malanje
# Processing Record 50 of Set 10 | hasaki
# Processing Record 1 of Set 11 | abu samrah
# Processing Record 2 of Set 11 | maragogi
# Processing Record 3 of Set 11 | aksha
# Processing Record 4 of Set 11 | santa rosa
# Processing Record 5 of Set 11 | natal
# Processing Record 6 of Set 11 | polovinnoye
# Processing Record 7 of Set 11 | skjervoy
# Processing Record 8 of Set 11 | pampierstad
# Processing Record 9 of Set 11 | bonavista
# Processing Record 10 of Set 11 | isangel
# Processing Record 11 of Set 11 | vincennes
# Processing Record 12 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 13 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 14 of Set 11 | comitan
# Processing Record 15 of Set 11 | gushikawa
# Processing Record 16 of Set 11 | sao borja
# Processing Record 17 of Set 11 | key west
# Processing Record 18 of Set 11 | helong
# Processing Record 19 of Set 11 | qasigiannguit
# Processing Record 20 of Set 11 | chimore
# Processing Record 21 of Set 11 | mana
# Processing Record 22 of Set 11 | sadiqabad
# Processing Record 23 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 24 of Set 11 | ambilobe
# Processing Record 25 of Set 11 | orsha
# Processing Record 26 of Set 11 | bambous virieux
# Processing Record 27 of Set 11 | mackay
# Processing Record 28 of Set 11 | tarnogskiy gorodok
# Processing Record 29 of Set 11 | mityana
# Processing Record 30 of Set 11 | elliot lake
# Processing Record 31 of Set 11 | constitucion
# Processing Record 32 of Set 11 | quatre cocos
# Processing Record 33 of Set 11 | pacific grove
# Processing Record 34 of Set 11 | kadoma
# Processing Record 35 of Set 11 | oranjestad
# Processing Record 36 of Set 11 | vieques
# Processing Record 37 of Set 11 | hambantota
# Processing Record 38 of Set 11 | milyutinskaya
# Processing Record 39 of Set 11 | halifax
# Processing Record 40 of Set 11 | walvis bay
# Processing Record 41 of Set 11 | kamenka
# Processing Record 42 of Set 11 | lampang
# Processing Record 43 of Set 11 | tawnat
# City not found. Skipping...
# Processing Record 44 of Set 11 | ruidoso
# Processing Record 45 of Set 11 | astipalaia
# City not found. Skipping...
# Processing Record 46 of Set 11 | biryukove
# Processing Record 47 of Set 11 | svetlogorsk
# Processing Record 48 of Set 11 | sioux lookout
# Processing Record 49 of Set 11 | luwuk
# Processing Record 50 of Set 11 | marquette
# Processing Record 1 of Set 12 | guajara-mirim
# City not found. Skipping...
# Processing Record 2 of Set 12 | touros
# Processing Record 3 of Set 12 | lithakia
# Processing Record 4 of Set 12 | suhbaatar
# Processing Record 5 of Set 12 | port hardy
# Processing Record 6 of Set 12 | yenagoa
# Processing Record 7 of Set 12 | bokspits
# City not found. Skipping...
# Processing Record 8 of Set 12 | charters towers
# Processing Record 9 of Set 12 | rincon
# Processing Record 10 of Set 12 | zhuhai
# Processing Record 11 of Set 12 | chumikan
# Processing Record 12 of Set 12 | ust-kuyga
# Processing Record 13 of Set 12 | tres barras
# Processing Record 14 of Set 12 | tlahualilo
# City not found. Skipping...
# Processing Record 15 of Set 12 | kavaratti
# Processing Record 16 of Set 12 | muroto
# Processing Record 17 of Set 12 | antofagasta
# Processing Record 18 of Set 12 | kaitangata
# Processing Record 19 of Set 12 | cheremukhovo
# Processing Record 20 of Set 12 | biltine
# Processing Record 21 of Set 12 | mantua
# Processing Record 22 of Set 12 | aptos
# Processing Record 23 of Set 12 | margate
# Processing Record 24 of Set 12 | nome
# Processing Record 25 of Set 12 | marawi
# Processing Record 26 of Set 12 | pundaguitan
# Processing Record 27 of Set 12 | jizan
# Processing Record 28 of Set 12 | beaupre
# Processing Record 29 of Set 12 | falam
# Processing Record 30 of Set 12 | shanghai
# Processing Record 31 of Set 12 | severobaykalsk
# Processing Record 32 of Set 12 | kihei
# Processing Record 33 of Set 12 | vardo
# Processing Record 34 of Set 12 | tevaitoa
# Processing Record 35 of Set 12 | yerbogachen
# Processing Record 36 of Set 12 | turbat
# Processing Record 37 of Set 12 | santiago de cao
# Processing Record 38 of Set 12 | kebemer
# City not found. Skipping...
# Processing Record 39 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 40 of Set 12 | thinadhoo
# Processing Record 41 of Set 12 | noumea
# Processing Record 42 of Set 12 | sobolevo
# Processing Record 43 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 44 of Set 12 | christchurch
# Processing Record 45 of Set 12 | varhaug
# Processing Record 46 of Set 12 | hermosillo
# Processing Record 47 of Set 12 | kodinsk
# Processing Record 48 of Set 12 | shache
# Processing Record 49 of Set 12 | porto santo
# Processing Record 50 of Set 12 | wolmaranstad
# City not found. Skipping...
# Processing Record 1 of Set 13 | mao
# Processing Record 2 of Set 13 | santa maria
# Processing Record 3 of Set 13 | agadez
# Processing Record 4 of Set 13 | severo-kurilsk
# Processing Record 5 of Set 13 | lazaro cardenas
# Processing Record 6 of Set 13 | epinal
# Processing Record 7 of Set 13 | emborion
# Processing Record 8 of Set 13 | bereda
# Processing Record 9 of Set 13 | twentynine palms
# Processing Record 10 of Set 13 | najran
# Processing Record 11 of Set 13 | ankpa
# Processing Record 12 of Set 13 | hanmer springs
# Processing Record 13 of Set 13 | pangnirtung
# Processing Record 14 of Set 13 | neyshabur
# Processing Record 15 of Set 13 | waddan
# Processing Record 16 of Set 13 | avera
# Processing Record 17 of Set 13 | ucluelet
# Processing Record 18 of Set 13 | mergui
# City not found. Skipping...
# Processing Record 19 of Set 13 | leshukonskoye
# Processing Record 20 of Set 13 | puerto narino
# Processing Record 21 of Set 13 | hobyo
# Processing Record 22 of Set 13 | sabang
# Processing Record 23 of Set 13 | goure
# Processing Record 24 of Set 13 | banda aceh
# Processing Record 25 of Set 13 | xichang
# Processing Record 26 of Set 13 | ramnagar
# Processing Record 27 of Set 13 | kutum
# Processing Record 28 of Set 13 | san angelo
# Processing Record 29 of Set 13 | sterling
# Processing Record 30 of Set 13 | kaputa
# Processing Record 31 of Set 13 | bria
# Processing Record 32 of Set 13 | crotone
# Processing Record 33 of Set 13 | llanes
# Processing Record 34 of Set 13 | wewak
# Processing Record 35 of Set 13 | severo-yeniseyskiy
# Processing Record 36 of Set 13 | araguatins
# City not found. Skipping...
# Processing Record 37 of Set 13 | kysyl-syr
# Processing Record 38 of Set 13 | taywarah
# Processing Record 39 of Set 13 | kabinda
# Processing Record 40 of Set 13 | cam ranh
# Processing Record 41 of Set 13 | anupgarh
# Processing Record 42 of Set 13 | thunder bay
# Processing Record 43 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 44 of Set 13 | los zacatones
# Processing Record 45 of Set 13 | havelock
# Processing Record 46 of Set 13 | kiboga
# Processing Record 47 of Set 13 | khromtau
# Processing Record 48 of Set 13 | stara tura
# Processing Record 49 of Set 13 | manado
# Processing Record 50 of Set 13 | kerouane
# Processing Record 1 of Set 14 | paulo afonso
# Processing Record 2 of Set 14 | talara
# Processing Record 3 of Set 14 | katangli
# Processing Record 4 of Set 14 | viedma
# Processing Record 5 of Set 14 | coxim
# Processing Record 6 of Set 14 | port hawkesbury
# Processing Record 7 of Set 14 | bambanglipuro
# Processing Record 8 of Set 14 | bontang
# Processing Record 9 of Set 14 | kegayli
# City not found. Skipping...
# Processing Record 10 of Set 14 | mecca
# Processing Record 11 of Set 14 | alofi
# Processing Record 12 of Set 14 | megion
# Processing Record 13 of Set 14 | buala
# Processing Record 14 of Set 14 | celestun
# Processing Record 15 of Set 14 | aquiraz
# Processing Record 16 of Set 14 | pangkalanbuun
# Processing Record 17 of Set 14 | eschwege
# Processing Record 18 of Set 14 | makasar
# Processing Record 19 of Set 14 | cerqueira cesar
# Processing Record 20 of Set 14 | opunake
# Processing Record 21 of Set 14 | irtyshskiy
# Processing Record 22 of Set 14 | puerto padre
# Processing Record 23 of Set 14 | kiruna
# Processing Record 24 of Set 14 | nantucket
# Processing Record 25 of Set 14 | caluquembe
# Processing Record 26 of Set 14 | leh
# Processing Record 27 of Set 14 | daru
# Processing Record 28 of Set 14 | srednekolymsk
# Processing Record 29 of Set 14 | acapulco
# Processing Record 30 of Set 14 | tabuk
# Processing Record 31 of Set 14 | necochea
# Processing Record 32 of Set 14 | alice springs
# Processing Record 33 of Set 14 | pavlodar
# Processing Record 34 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 35 of Set 14 | fonte boa
# Processing Record 36 of Set 14 | port-gentil
# Processing Record 37 of Set 14 | paita
# Processing Record 38 of Set 14 | wajima
# Processing Record 39 of Set 14 | bani
# Processing Record 40 of Set 14 | cururupu
# Processing Record 41 of Set 14 | zyryanka
# Processing Record 42 of Set 14 | chiredzi
# Processing Record 43 of Set 14 | brae
# Processing Record 44 of Set 14 | chizhou
# Processing Record 45 of Set 14 | dzhebariki-khaya
# Processing Record 46 of Set 14 | kropotkin
# Processing Record 47 of Set 14 | partapur
# Processing Record 48 of Set 14 | chernyshevskiy
# Processing Record 49 of Set 14 | wanning
# Processing Record 50 of Set 14 | nikolayevsk-na-amure
# Processing Record 1 of Set 15 | patiya
# Processing Record 2 of Set 15 | hualmay
# Processing Record 3 of Set 15 | maneadero
# Processing Record 4 of Set 15 | jibuti
# Processing Record 5 of Set 15 | hirara
# Processing Record 6 of Set 15 | grand gaube
# Processing Record 7 of Set 15 | marion
# Processing Record 8 of Set 15 | miraflores
# Processing Record 9 of Set 15 | kovdor
# Processing Record 10 of Set 15 | bar harbor
# Processing Record 11 of Set 15 | caraquet
# Processing Record 12 of Set 15 | muros
# Processing Record 13 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 14 of Set 15 | hervey bay
# Processing Record 15 of Set 15 | kochki
# Processing Record 16 of Set 15 | hailar
# Processing Record 17 of Set 15 | zyryanovsk
# Processing Record 18 of Set 15 | hofn
# Processing Record 19 of Set 15 | zhangye
# Processing Record 20 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 21 of Set 15 | shirgaon
# Processing Record 22 of Set 15 | rolim de moura
# City not found. Skipping...
# Processing Record 23 of Set 15 | bulolo
# Processing Record 24 of Set 15 | polunochnoye
# Processing Record 25 of Set 15 | rafraf
# Processing Record 26 of Set 15 | svetlaya
# Processing Record 27 of Set 15 | maua
# Processing Record 28 of Set 15 | sao desiderio
# Processing Record 29 of Set 15 | bang saphan
# Processing Record 30 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 31 of Set 15 | kerema
# Processing Record 32 of Set 15 | saint anthony
# Processing Record 33 of Set 15 | pousat
# City not found. Skipping...
# Processing Record 34 of Set 15 | noyabrsk
# Processing Record 35 of Set 15 | puruandiro
# Processing Record 36 of Set 15 | ottumwa
# Processing Record 37 of Set 15 | langsa
# Processing Record 38 of Set 15 | polis
# Processing Record 39 of Set 15 | shirvan
# Processing Record 40 of Set 15 | huazolotitlan
# City not found. Skipping...
# Processing Record 41 of Set 15 | kasane
# Processing Record 42 of Set 15 | bur gabo
# City not found. Skipping...
# Processing Record 43 of Set 15 | clifton
# Processing Record 44 of Set 15 | bocas del toro
# Processing Record 45 of Set 15 | shimoda
# Processing Record 46 of Set 15 | bilma
# Processing Record 47 of Set 15 | mirnyy
# Processing Record 48 of Set 15 | colesberg
# Processing Record 49 of Set 15 | krasnoarmeysk
# Processing Record 50 of Set 15 | mahajanga
# Processing Record 1 of Set 16 | chambas
# Processing Record 2 of Set 16 | poya
# Processing Record 3 of Set 16 | yanan
# City not found. Skipping...
# Processing Record 4 of Set 16 | gasa
# Processing Record 5 of Set 16 | zhanakorgan
# Processing Record 6 of Set 16 | shelburne
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[city_data_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Yar-Sale      RU  66.8333   70.8333     39.97        83         100
# 1     Cape Town      ZA -33.9258   18.4232     60.39        87          19
# 2      Cherskiy      RU  68.7500  161.3000     52.00        68          97
# 3  Ponta Do Sol      PT  32.6667  -17.1000     77.00        84          97
# 4       Sawakin      SD  19.1059   37.3321     86.23        72          36
# 5    Chokurdakh      RU  70.6333  147.9167     41.05        88         100
# 6     Upernavik      GL  72.7868  -56.1549     43.03        95         100
# 7       Utamysh      RU  42.4072   47.7511     58.73        96         100
# 8        Atuona      PF  -9.8000 -139.0333     77.02        73           5
# 9  Punta Arenas      CL -53.1500  -70.9167     46.51        61           0
#
#    Wind Speed Current Description
# 0        5.19     overcast clouds
# 1        1.99          few clouds
# 2        1.95          light rain
# 3        5.14     overcast clouds
# 4        3.09    scattered clouds
# 5        4.54     overcast clouds
# 6        5.93          light rain
# 7        4.92       moderate rain
# 8       19.53           clear sky
# 9       13.80           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
